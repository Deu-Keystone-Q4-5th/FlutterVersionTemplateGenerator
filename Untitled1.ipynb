# %%
pip install pandas

# %%
import csv
df = pd.read_csv('/content/books_updated.csv',)
df
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

book = pd.read_csv('/content/books_updated.csv')

keywords = input('검색할 분야를 입력하시오 : ')

if keywords == 'authors':
        name = input('authors의 이름을 입력하시오 : ')
        print('해당하는 작가의 작품입니다\n')
        print(book[book['authors'] == name])

elif keywords == 'tag_name':
         name = input('tag_name을 입력하시오 : ').split()
         print(' :', book['tag_name'])

elif keywords == 'currently_reading':
         name = input('currently_reading을 입력하시오 : ').split()
         print('의 재고 :', book['currently_reading'])
# Out:
# 검색할 분야를 입력하시오 : authors
# authors의 이름을 입력하시오 : John Keegan
# 해당하는 작가의 작품입니다
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fa6d47e0dbec> in <cell line: 10>()
#      11         name = input('authors의 이름을 입력하시오 : ')
#      12         print('해당하는 작가의 작품입니다\n')
# ---> 13         print(df = book[book['authors'] == name])
#      14
#      15 elif keywords == 'tag_name':
#
# TypeError: 'df' is an invalid keyword argument for print()
